# %%
import pandas as pd
import numpy as np;

# %%
train_df = pd.read_csv('/Users/merveayaz/Desktop/datathon-2024/train.csv')
train_df
# Out:
# /var/folders/l2/hnzwcxts0pvg_y0r444gbbt00000gn/T/ipykernel_16637/2479035249.py:1: DtypeWarning: Columns (13,15,19,30,32,37,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('/Users/merveayaz/Desktop/datathon-2024/train.csv')
#        Basvuru Yili  Degerlendirme Puani Cinsiyet      Dogum Tarihi  \
# 0              2014                 52.0    Erkek          4/6/1994
# 1              2014                 30.0    Erkek         6/11/1993
# 2              2014                 18.0    Erkek         1/15/1986
# 3              2014                 40.0    Erkek          6/4/1991
# 4              2014                 24.0    Erkek      2 Kasim 1992
# ...             ...                  ...      ...               ...
# 65120          2022                  0.0    Erkek  18.06.2003 00:00
# 65121          2022                  0.0    Erkek  18.04.2002 00:00
# 65122          2022                  0.0    Erkek  23.10.1999 00:00
# ...

# %%
train_df.head()
# Out:
#    Basvuru Yili  Degerlendirme Puani Cinsiyet  Dogum Tarihi        Dogum Yeri  \
# 0          2014                 52.0    Erkek      4/6/1994  Altindag, Ankara
# 1          2014                 30.0    Erkek     6/11/1993           Üsküdar
# 2          2014                 18.0    Erkek     1/15/1986            Samsun
# 3          2014                 40.0    Erkek      6/4/1991        Diyarbakır
# 4          2014                 24.0    Erkek  2 Kasim 1992   Ankara/Altındağ
#
#   Ikametgah Sehri                    Universite Adi Universite Turu  \
# 0          Ankara           İHSAN DOĞRAMACI BİLKENT            Özel
# 1        İstanbul           İHSAN DOĞRAMACI BİLKENT            Özel
# 2        İstanbul  ULUSLARARASI KIBRIS ÜNİVERSİTESİ            Özel
# 3        İstanbul       İSTANBUL ŞEHİR ÜNİVERSİTESİ            Özel
# 4          Ankara          TURGUT ÖZAL ÜNİVERSİTESİ            Özel
#
#    Burslu ise Burs Yuzdesi Burs Aliyor mu?  ... Spor Dalindaki Rolunuz Nedir?  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65125 entries, 0 to 65124
# Data columns (total 44 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Basvuru Yili                                               65125 non-null  int64
#  1   Degerlendirme Puani                                        65124 non-null  float64
#  2   Cinsiyet                                                   64956 non-null  object
#  3   Dogum Tarihi                                               64948 non-null  object
#  4   Dogum Yeri                                                 64334 non-null  object
#  5   Ikametgah Sehri                                            63088 non-null  object
#  6   Universite Adi                                             64993 non-null  object
# ...

# %%
train_df["Degerlendirme Puani"].describe()
# Out:
# count    65124.000000
# mean        32.086466
# std         18.139239
# min          0.000000
# 25%         18.000000
# 50%         29.000000
# 75%         44.000000
# max        102.000000
# Name: Degerlendirme Puani, dtype: float64

# %%
print(train_df.columns)
# Out:
# Index(['Basvuru Yili', 'Degerlendirme Puani', 'Cinsiyet', 'Dogum Tarihi',
#        'Dogum Yeri', 'Ikametgah Sehri', 'Universite Adi', 'Universite Turu',
#        'Burslu ise Burs Yuzdesi', 'Burs Aliyor mu?', 'Bölüm',
#        'Universite Kacinci Sinif', 'Universite Not Ortalamasi',
#        'Daha Once Baska Bir Universiteden Mezun Olmus', 'Lise Adi',
#        'Lise Adi Diger', 'Lise Sehir', 'Lise Turu', 'Lise Bolumu',
#        'Lise Bolum Diger', 'Lise Mezuniyet Notu',
#        'Baska Bir Kurumdan Burs Aliyor mu?', 'Burs Aldigi Baska Kurum',
#        'Baska Kurumdan Aldigi Burs Miktari', 'Anne Egitim Durumu',
#        'Anne Calisma Durumu', 'Anne Sektor', 'Baba Egitim Durumu',
#        'Baba Calisma Durumu', 'Baba Sektor', 'Kardes Sayisi',
#        'Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?',
#        'Uye Oldugunuz Kulubun Ismi',
#        'Profesyonel Bir Spor Daliyla Mesgul musunuz?',
#        'Spor Dalindaki Rolunuz Nedir?', 'Aktif olarak bir STK üyesi misiniz?',
# ...

# %%
train_df["Cinsiyet"].value_counts()
# Out:
# Cinsiyet
# Kadın                    32077
# Erkek                    22752
# ERKEK                    10012
# Belirtmek istemiyorum      115
# Name: count, dtype: int64

# %%
print(train_df["Cinsiyet"])
# Out:
# 0        Erkek
# 1        Erkek
# 2        Erkek
# 3        Erkek
# 4        Erkek
#          ...
# 65120    Erkek
# 65121    Erkek
# 65122    Erkek
# 65123    Erkek
# 65124    Kadın
# Name: Cinsiyet, Length: 65125, dtype: object

# %%
train_df["Cinsiyet"] = train_df["Cinsiyet"].str.lower()

# %%
train_df["Cinsiyet"].value_counts()
# Out:
# Cinsiyet
# erkek                    32764
# kadın                    32077
# belirtmek istemiyorum      115
# Name: count, dtype: int64

# %%
train_df["Bölüm"].value_counts()
# Out:
# Bölüm
# Endüstri Mühendisliği               2434
# İşletme                             2318
# Bilgisayar Mühendisliği             1917
# Hukuk                               1769
# Makine Mühendisliği                 1283
#                                     ...
# Matematik Muhendisliği                 1
# İlahiyat Fakultesi                     1
# Petrol ve Doğal Gaz Mühendsiliği       1
# radyo,sinema ve televizyon             1
# Nanoteknoloji Mühendisliği             1
# Name: count, Length: 7748, dtype: int64

# %%
train_df["Burs Aliyor mu?"].value_counts()
# Out:
# Burs Aliyor mu?
# Hayır    51978
# Evet      9289
# EVET      3475
# hayır      272
# evet       111
# Name: count, dtype: int64

# %%
train_df = train_df.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

# %%
train_df["Burs Aliyor mu?"].value_counts()
# Out:
# Burs Aliyor mu?
# hayır    52250
# evet     12875
# Name: count, dtype: int64

# %%
train_df["Bölüm"].value_counts()
# Out:
# Bölüm
# endüstri mühendisliği                                                                     2697
# i̇şletme                                                                                  2512
# bilgisayar mühendisliği                                                                   2137
# hukuk                                                                                     2007
# makine mühendisliği                                                                       1470
#                                                                                           ...
# elektronik - haberleşme mühendisliği / kontrol mühendisliği çift anadal programı / çap       1
# türk dili ve edebiyatı/tarih çift anadal                                                     1
# biyo muhendislik                                                                             1
# çevre muhendisliği                                                                           1
# ...

# %%
house_num = train_df.select_dtypes(include = ['float64', 'int64'])
hous_num_corr = house_num.corr()['Degerlendirme Puani'][:1] 
top_features = hous_num_corr[abs(hous_num_corr) > 0.5].sort_values(ascending=False) #displays pearsons correlation coefficient greater than 0.5
print("There is {} strongly correlated values with Degerlendirme Puani:\n{}".format(len(top_features), top_features))
# Out:
# There is 0 strongly correlated values with Degerlendirme Puani:
# Series([], Name: Degerlendirme Puani, dtype: float64)

# %%
import seaborn as sns

# %%
dp_untransformed = sns.histplot(train_df["Degerlendirme Puani"])
# Out:
# /opt/miniconda3/envs/testenv/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print("Skewness: %f" % train_df["Degerlendirme Puani"].skew())
# Out:
# Skewness: 0.630144

# %%
log_transformed = np.log(train_df["Degerlendirme Puani"])
# Out:
# /opt/miniconda3/envs/testenv/lib/python3.9/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
dp_untransformed = sns.histplot(log_transformed)
# Out:
# /opt/miniconda3/envs/testenv/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dublicate = train_df[train_df.duplicated(["id"])]
dublicate
# Out:
# Empty DataFrame
# ...

# %%
import matplotlib.pylab as plt

# %%
total = train_df.isnull().sum().sort_values(ascending=False)
total_select = total.head(20)
total_select.plot(kind="bar", figsize = (8,6), fontsize = 10)

plt.xlabel("columns", fontsize = 20)
plt.ylabel("count", fontsize = 20)
plt.title("total missing values", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'total missing values')

# %% [markdown]
# from sklearn.impute import KNNImputer
# from sklearn.preprocessing import OrdinalEncoder
#
# # Encode categorical columns
# ordinal_encoder = OrdinalEncoder()
# train_df_encoded = ordinal_encoder.fit_transform(train_df.select_dtypes(include=['object']))
#
# # Apply KNN Imputer
# imputer = KNNImputer(n_neighbors=5)
# train_df_imputed = imputer.fit_transform(train_df_encoded)
#
# # Convert back to original categories
# train_df_imputed = ordinal_encoder.inverse_transform(train_df_imputed)

# %%
test_df = pd.read_csv('/Users/merveayaz/Desktop/datathon-2024/test_x.csv')
test_df
# Out:
#        Basvuru Yili Cinsiyet      Dogum Tarihi Dogum Yeri Ikametgah Sehri  \
# 0              2023    Kadın  21.06.2002 00:00     Amasya          Amasya
# 1              2023    Kadın  11.05.2004 00:00      Konya           Konya
# 2              2023    Erkek  24.04.2002 00:00   İstanbul        İstanbul
# 3              2023    Erkek  11.03.2003 00:00     Mardin          Mardin
# 4              2023    Erkek  26.01.2002 00:00     Samsun        İstanbul
# ...             ...      ...               ...        ...             ...
# 11044          2023    Kadın   3.01.2002 00:00     Yozgat          Ankara
# 11045          2023    Kadın   9.09.2001 00:00      Konya           Konya
# 11046          2023    Erkek   8.06.2004 00:00     Ankara          Ankara
# 11047          2023    Kadın  16.10.2001 00:00   Adıyaman        İstanbul
# 11048          2023    Kadın  22.09.1999 00:00      Niğde          Ankara
#
#                            Universite Adi Universite Turu  \
# ...

# %%
test_df['Degerlendirme Puani'] = pd.Series([train_df['Degerlendirme Puani'].mean()]*len(train_df))
test_df
# Out:
#        Basvuru Yili Cinsiyet      Dogum Tarihi Dogum Yeri Ikametgah Sehri  \
# 0              2023    Kadın  21.06.2002 00:00     Amasya          Amasya
# 1              2023    Kadın  11.05.2004 00:00      Konya           Konya
# 2              2023    Erkek  24.04.2002 00:00   İstanbul        İstanbul
# 3              2023    Erkek  11.03.2003 00:00     Mardin          Mardin
# 4              2023    Erkek  26.01.2002 00:00     Samsun        İstanbul
# ...             ...      ...               ...        ...             ...
# 11044          2023    Kadın   3.01.2002 00:00     Yozgat          Ankara
# 11045          2023    Kadın   9.09.2001 00:00      Konya           Konya
# 11046          2023    Erkek   8.06.2004 00:00     Ankara          Ankara
# 11047          2023    Kadın  16.10.2001 00:00   Adıyaman        İstanbul
# 11048          2023    Kadın  22.09.1999 00:00      Niğde          Ankara
#
#                            Universite Adi Universite Turu  \
# ...

# %%
test_df[["id", "Degerlendirme Puani"]].to_csv("average_prediction.csv", index=False)
